# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#1.-Characterize-the-Airbnb-locations-distribution-in-the-city" data-toc-modified-id="1.-Characterize-the-Airbnb-locations-distribution-in-the-city-1">1. Characterize the Airbnb locations distribution in the city</a></span><ul class="toc-item"><li><span><a href="#1.1.-Prepare-data" data-toc-modified-id="1.1.-Prepare-data-1.1">1.1. Prepare data</a></span><ul class="toc-item"><li><span><a href="#1.1.1.-Finish-to-clean-data-set" data-toc-modified-id="1.1.1.-Finish-to-clean-data-set-1.1.1">1.1.1. Finish to clean data set</a></span></li><li><span><a href="#1.1.2.-Add-information-about-safety-and-green-areas-in-the-data-set" data-toc-modified-id="1.1.2.-Add-information-about-safety-and-green-areas-in-the-data-set-1.1.2">1.1.2. Add information about safety and green areas in the data set</a></span></li><li><span><a href="#1.1.3.-Create-subset-for-further-analysis" data-toc-modified-id="1.1.3.-Create-subset-for-further-analysis-1.1.3">1.1.3. Create subset for further analysis</a></span></li></ul></li><li><span><a href="#1.2.-We-expect-to-find-more-Airbnb-locations-and-bookigs-in-the-most-popular-and-centric-neighbourhoods." data-toc-modified-id="1.2.-We-expect-to-find-more-Airbnb-locations-and-bookigs-in-the-most-popular-and-centric-neighbourhoods.-1.2">1.2. We expect to find more Airbnb locations and bookigs in the most popular and centric neighbourhoods.</a></span><ul class="toc-item"><li><span><a href="#1.2.1.-How-many-listings-we-find-per-district-and-neighbourhood?" data-toc-modified-id="1.2.1.-How-many-listings-we-find-per-district-and-neighbourhood?-1.2.1">1.2.1. How many listings we find per district and neighbourhood?</a></span></li><li><span><a href="#1.2.2.-How-many-bokkings/reviews-we-find-in-every-disctrict/-neighbourhood?" data-toc-modified-id="1.2.2.-How-many-bokkings/reviews-we-find-in-every-disctrict/-neighbourhood?-1.2.2">1.2.2. How many bokkings/reviews we find in every disctrict/ neighbourhood?</a></span></li><li><span><a href="#1.2.3.-Are-there-more-types-of-room-in-one-neihbourhood-than-the-other-and-in-Amstertdam?" data-toc-modified-id="1.2.3.-Are-there-more-types-of-room-in-one-neihbourhood-than-the-other-and-in-Amstertdam?-1.2.3">1.2.3. Are there more types of room in one neihbourhood than the other and in Amstertdam?</a></span></li><li><span><a href="#1.2.4.-How-are-the-neighbourhoods-according-to-the-desciptors?" data-toc-modified-id="1.2.4.-How-are-the-neighbourhoods-according-to-the-desciptors?-1.2.4">1.2.4. How are the neighbourhoods according to the desciptors?</a></span></li></ul></li><li><span><a href="#1.3.-We-expect-to-find-more-locations-and-bookings-where-there-are-more-green-areas-and-less-criminality." data-toc-modified-id="1.3.-We-expect-to-find-more-locations-and-bookings-where-there-are-more-green-areas-and-less-criminality.-1.3">1.3. We expect to find more locations and bookings where there are more green areas and less criminality.</a></span><ul class="toc-item"><li><span><a href="#1.3.1.-Is-the-number-of-listings-and-bookings-per-neihbourhood-correlated-to-the-green-areas-and-the-number-of-crimes?" data-toc-modified-id="1.3.1.-Is-the-number-of-listings-and-bookings-per-neihbourhood-correlated-to-the-green-areas-and-the-number-of-crimes?-1.3.1">1.3.1. Is the number of listings and bookings per neihbourhood correlated to the green areas and the number of crimes?</a></span></li></ul></li></ul></li><li><span><a href="#2.-Compare-how-the-available-locations-have-change-during-this-period-(number-of-locations-available,-type-of-locations...)" data-toc-modified-id="2.-Compare-how-the-available-locations-have-change-during-this-period-(number-of-locations-available,-type-of-locations...)-2">2. Compare how the available locations have change during this period (number of locations available, type of locations...)</a></span><ul class="toc-item"><li><span><a href="#2.1.-A-decrease-of-locations-availability-for-the-corona-period" data-toc-modified-id="2.1.-A-decrease-of-locations-availability-for-the-corona-period-2.1">2.1. A decrease of locations availability for the corona period</a></span><ul class="toc-item"><li><span><a href="#2.1.2-Number-of-locations-per-date" data-toc-modified-id="2.1.2-Number-of-locations-per-date-2.1.1">2.1.2 Number of locations per date</a></span></li><li><span><a href="#2.1.2-Number-of-locations-per-district-per-date" data-toc-modified-id="2.1.2-Number-of-locations-per-district-per-date-2.1.2">2.1.2 Number of locations per district per date</a></span></li></ul></li><li><span><a href="#2.2.-We-expect-less-accommodations-available" data-toc-modified-id="2.2.-We-expect-less-accommodations-available-2.2">2.2. We expect less accommodations available</a></span><ul class="toc-item"><li><span><a href="#2.2.1.-Locations-availability-per-date-x-type-of-room" data-toc-modified-id="2.2.1.-Locations-availability-per-date-x-type-of-room-2.2.1">2.2.1. Locations availability per date x type of room</a></span></li></ul></li><li><span><a href="#2.3.-We-expect-more-fuller-house-renting-than-rooms" data-toc-modified-id="2.3.-We-expect-more-fuller-house-renting-than-rooms-2.3">2.3. We expect more fuller house renting than rooms</a></span></li><li><span><a href="#2.4.-An-impact-on-the-price-between-pandemic-and-pre-pandemic" data-toc-modified-id="2.4.-An-impact-on-the-price-between-pandemic-and-pre-pandemic-2.4">2.4. An impact on the price between pandemic and pre pandemic</a></span><ul class="toc-item"><li><span><a href="#2.4.1.-Distribution-of-price" data-toc-modified-id="2.4.1.-Distribution-of-price-2.4.1">2.4.1. Distribution of price</a></span></li><li><span><a href="#2.4.2.-Average-price-per-date" data-toc-modified-id="2.4.2.-Average-price-per-date-2.4.2">2.4.2. Average price per date</a></span></li><li><span><a href="#2.4.3.-Average-price-district" data-toc-modified-id="2.4.3.-Average-price-district-2.4.3">2.4.3. Average price district</a></span></li><li><span><a href="#2.4.4.-Average-price-x-date-x-district" data-toc-modified-id="2.4.4.-Average-price-x-date-x-district-2.4.4">2.4.4. Average price x date x district</a></span></li></ul></li></ul></li><li><span><a href="#3.-Analyse-the-changes-on-prices,-availability-and-bookings-during-corona-period" data-toc-modified-id="3.-Analyse-the-changes-on-prices,-availability-and-bookings-during-corona-period-3">3. Analyse the changes on prices, availability and bookings during corona period</a></span><ul class="toc-item"><li><span><a href="#3.1.-Prepare-the-data" data-toc-modified-id="3.1.-Prepare-the-data-3.1">3.1. Prepare the data</a></span></li><li><span><a href="#3.2.-Price-per-type-of-rental" data-toc-modified-id="3.2.-Price-per-type-of-rental-3.2">3.2. Price per type of rental</a></span></li><li><span><a href="#3.3.-Weekend-no-weekend,-booked-rentals" data-toc-modified-id="3.3.-Weekend-no-weekend,-booked-rentals-3.3">3.3. Weekend no weekend, booked rentals</a></span></li><li><span><a href="#3.4.-A-fluctuation-on-the-prices-during-this-period-should-follow-a-pattern-according-to-the-country-restrictions-of-mobility-and-touristic-activities" data-toc-modified-id="3.4.-A-fluctuation-on-the-prices-during-this-period-should-follow-a-pattern-according-to-the-country-restrictions-of-mobility-and-touristic-activities-3.4">3.4. A fluctuation on the prices during this period should follow a pattern according to the country restrictions of mobility and touristic activities</a></span><ul class="toc-item"><li><span><a href="#3.3.1.-Exploring-the-price" data-toc-modified-id="3.3.1.-Exploring-the-price-3.4.1">3.3.1. Exploring the price</a></span></li><li><span><a href="#3.3.2.--Average-price-per-day-over-the-years" data-toc-modified-id="3.3.2.--Average-price-per-day-over-the-years-3.4.2">3.3.2.  Average price per day over the years</a></span></li><li><span><a href="#3.3.3.--Average-price-per-year" data-toc-modified-id="3.3.3.--Average-price-per-year-3.4.3">3.3.3.  Average price per year</a></span></li></ul></li><li><span><a href="#3.5.-A-fluctuation-on-the-bookings-during-this-period-should-follow-a-pattern-according-to-the-country-restrictions-of-mobility-and-touristic-activities" data-toc-modified-id="3.5.-A-fluctuation-on-the-bookings-during-this-period-should-follow-a-pattern-according-to-the-country-restrictions-of-mobility-and-touristic-activities-3.5">3.5. A fluctuation on the bookings during this period should follow a pattern according to the country restrictions of mobility and touristic activities</a></span></li><li><span><a href="#3.6.-A-decrease-of-bookings-on-single-rooms-renting-compare-to-entire-rentals." data-toc-modified-id="3.6.-A-decrease-of-bookings-on-single-rooms-renting-compare-to-entire-rentals.-3.6">3.6. A decrease of bookings on single rooms renting compare to entire rentals.</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Airbnb in Amsterdam during COVID 19

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
#  ## 1. Characterize the Airbnb locations distribution in the city

# %% [markdown]
# ### 1.1. Prepare data

# %% [markdown]
# The data set all_date_listings has all the listings availables for 4 dates:
#     - December 2018
#     - April 2020
#     - December 2020
#     - April 2021
#
# For every date there is a entry for each listing/location. It has data about the type of accomodation, the location in the city, the district and neigbourhood it belongs, the total number of reviews accumulated till that date, the average review received, and the average price,...

# %%
all_dates_listings = pd.read_csv("../data/clean_data/all_dates_listings.csv")

# %% [markdown]
# #### 1.1.1. Finish to clean data set

# %%
all_dates_listings.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'host_id', 'host_name', 'neighbourhood',
#        'latitude', 'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365', 'Date',
#        'District_code', 'District'],
#       dtype='object')

# %%
#we will keep those columns
listings= all_dates_listings[['id','neighbourhood','latitude', 'longitude', 'room_type', 'price', 'minimum_nights',
                   'number_of_reviews','reviews_per_month','calculated_host_listings_count', 
                   'availability_365', 'Date','District_code','District']]

# %%
#The missing values are because they did not have reviews, therefore must be better to just fill those
#values with 0
listings['reviews_per_month'].fillna(0,inplace=True)
# Out:
# /Users/lauratll/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %% [markdown]
# #### 1.1.2. Add information about safety and green areas in the data set

# %%
district_descriptors = pd.read_csv("../data/clean_data/district_descriptors.csv")
district_descriptors = district_descriptors.iloc[:,1:]
district_descriptors
# Out:
#    District_name District_code   type_of_crime  average_number_of_crimes  \
# 0        Centrum             A           abuse                    887.00
# 1        Centrum             A          murder                     42.00
# 2        Centrum             A   open violence                     68.00
# 3        Centrum             A         robbery                     15.67
# 4        Centrum             A  street robbery                    277.33
# 5        Centrum             A          threat                    411.00
# 6     Nieuw-West             F           abuse                    614.67
# 7     Nieuw-West             F          murder                     46.67
# 8     Nieuw-West             F   open violence                     31.00
# 9     Nieuw-West             F         robbery                     51.00
# 10    Nieuw-West             F  street robbery                    130.00
# 11    Nieuw-West             F          threat                    500.00
# ...

# %%
district_descriptors = district_descriptors.groupby(["District_name","District_code"]).agg(
    {"average_number_of_crimes":"sum","green_areas_m2":"mean","num_green_areas":"mean"}).reset_index()

district_descriptors = district_descriptors.rename(columns={"District_name":"District"})
listings_with_descriptors = listings.merge(district_descriptors, left_on=['District_code',"District"],right_on=['District_code',"District"],how="left")
listings_with_descriptors
# Out:
#              id                           neighbourhood   latitude  longitude  \
# 0          2818  Oostelijk Havengebied - Indische Buurt  52.365755   4.941419
# 1          3209                              Westerpark  52.390225   4.873924
# 2         20168                            Centrum-Oost  52.365087   4.893541
# 3         25428                            Centrum-West  52.373114   4.883668
# 4         27886                            Centrum-West  52.386727   4.892078
# ...         ...                                     ...        ...        ...
# 75734  49085366                            Centrum-West  52.372200   4.899260
# 75735  49089176                 De Pijp - Rivierenbuurt  52.354160   4.887000
# 75736  49101225                                Oud-Oost  52.355720   4.924400
# 75737  49102514                  Buitenveldert - Zuidas  52.336560   4.848350
# 75738  49119460                            Centrum-West  52.374660   4.880550
#
# ...

# %% [markdown]
# #### 1.1.3. Create subset for further analysis

# %%
#listings_with_descriptors_dec....

# %%
#listings_with_descriptors_april

# %% [markdown]
# ### 1.2. We expect to find more Airbnb locations and bookigs in the most popular and centric neighbourhoods.

# %%
#I could use a map from Tableau to iustrate

# %% [markdown]
# #### 1.2.1. How many listings we find per district and neighbourhood?

# %%
#we use this one as is the more actualized
listings_april_21 = listings_with_descriptors.loc[listings_with_descriptors["Date"]=="April 2021"]
listings_april_21.head()
# Out:
#           id                           neighbourhood  latitude  longitude  \
# 57914   2818  Oostelijk Havengebied - Indische Buurt  52.36435    4.94358
# 57915  20168                            Centrum-Oost  52.36407    4.89393
# 57916  25428                            Centrum-West  52.37490    4.88487
# 57917  27886                            Centrum-West  52.38761    4.89188
# 57918  28871                            Centrum-West  52.36775    4.89092
#
#              room_type   price  minimum_nights  number_of_reviews  \
# 57914     Private room   49.56               3                278
# 57915     Private room  168.00               1                339
# 57916  Entire home/apt  105.00              14                  5
# 57917     Private room  118.44               2                219
# 57918     Private room   63.00               2                336
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# ...

# %%
listings_april_21_district = listings_april_21.groupby(["District"])["id"].count().sort_values(
    ascending=False).reset_index()
listings_april_21_district
# Out:
#      District    id
# 0        West  5298
# 1        Zuid  3774
# 2     Centrum  3472
# 3        Oost  2924
# 4       Noord  1198
# 5  Nieuw-West   840
# 6    Zuidoost   319

# %%
#plt.style.use('fivethirtyeight')
fig, ax = plt.subplots(1,1,figsize = (12,8),sharex=True)

fig.suptitle('Number of locations x district', size='20', fontweight='bold')

data= listings_april_21_district

sns.barplot(x = "District",y = "id", ax = ax, data=data)
ax.set_ylabel("number of listings")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("../figures/num_locations_x_disctrict.png",dpi=600)
plt.show()

# %%
#i will look at the neihbourhoods as well

listings_april_21_neigh = listings_april_21.groupby(["District",
                                                     "neighbourhood"])["id"].count().sort_values(
    ascending=False).reset_index()

listings_april_21_neigh.head()
# Out:
#   District            neighbourhood    id
# 0     West   De Baarsjes - Oud-West  2965
# 1     Zuid  De Pijp - Rivierenbuurt  2223
# 2  Centrum             Centrum-West  1982
# 3  Centrum             Centrum-Oost  1490
# 4     Zuid                     Zuid  1321

# %%
fig, ax = plt.subplots(1,1,figsize = (12,8),sharex=True)

fig.suptitle('Locations x neighbourhood', size='20', fontweight='bold')

data= listings_april_21_neigh

sns.barplot(x = "neighbourhood",y = "id", ax = ax, data=data)
ax.set_ylabel("number of listings")
plt.xticks(rotation=90)
plt.tight_layout()

# %%
listings_april_21_neigh = listings_april_21_neigh.set_index(["District","neighbourhood"])

# %%
def plot_function(x, ax,df):
    ax = graph[x]
    ax.set_xlabel(x, weight='bold')
    ax.set_ylabel("number of listings")
    return df.xs(x).plot(kind='bar', stacked='True', ax=ax, legend=False).set_xlabel(x, weight='bold')

# plots = list(map(lambda x: serotype_df.xs(x).plot(
#     kind='bar', stacked='True', ax=graph[x], legend=False).set_xlabel(x, weight='bold'), graph))

# %%
n_subplots = len(listings_april_21_neigh.index.levels[0])
fig, axes = plt.subplots(nrows=1, ncols=n_subplots, sharey=True, figsize=(14, 8))  # width, height
graph = dict(zip(listings_april_21_neigh.index.levels[0], axes))
plots = list(map(lambda x: plot_function(x, graph[x],listings_april_21_neigh), graph))
ax.tick_params(axis='both', which='both', length=0)
fig.subplots_adjust(wspace=0)
plt.show()

# %% [markdown]
# #### 1.2.2. How many bokkings/reviews we find in every disctrict/ neighbourhood?

# %%
#because there are more listings in certain neighbourhoods, I am gonna divide the numbers of reviews by the
#number of listings
listings_april_21_rew = listings_april_21.groupby(["District"]).agg({"number_of_reviews":"sum","id":"count"}).reset_index()

# %%
listings_april_21.groupby(["District"]).agg({"number_of_reviews":"mean"})
# Out:
#             number_of_reviews
# District
# Centrum             37.548675
# Nieuw-West          23.366667
# Noord               24.782972
# Oost                18.545144
# West                19.979049
# Zuid                20.805246
# Zuidoost            27.206897

# %%
listings_april_21_rew["rev/locations"] = listings_april_21_rew["number_of_reviews"]/listings_april_21_rew["id"]

# %%
listings_april_21_rew.head()
# Out:
#      District  number_of_reviews    id  rev/locations
# 0     Centrum             130369  3472      37.548675
# 1  Nieuw-West              19628   840      23.366667
# 2       Noord              29690  1198      24.782972
# 3        Oost              54226  2924      18.545144
# 4        West             105849  5298      19.979049

# %%
plt.style.use('fivethirtyeight')
fig, ax = plt.subplots(1,1,figsize = (12,8),sharex=True)

fig.suptitle('Location x district', size='20', fontweight='bold')

#we take 200 as the 75quartile of the whole data set is around 160
data= listings_april_21.groupby(["District"])["number_of_reviews"].sum().reset_index()

sns.barplot(x = "District",y = "number_of_reviews", ax = ax, data=data)
ax.set_ylabel("number of reviews")
plt.xticks(rotation=45)
plt.tight_layout()


plt.show()

# %%
#average number of reviews x district

#plt.style.use('fivethirtyeight')fig, ax = plt.subplots(1,1,figsize = (12,8),sharex=True)

fig.suptitle('Location x district', size='20', fontweight='bold')

#we take 200 as the 75quartile of the whole data set is around 160
data= listings_april_21_rew

sns.barplot(x = "District",y = "rev/locations", ax = ax, data=data)
ax.set_ylabel("number of reviews/number of locations")
plt.xticks(rotation=45)
plt.tight_layout()

plt.savefig("../figures/index_rew_loc_x_district.png",dpi=600)

plt.show()

# %%
###more bookings in the center...
###as we use this index as an indicator, we can see now that for neigbourhoods with less listing and maybe a lot
#of reviews like Zuidoost....

# %%
rev_april_21 = listings_april_21.groupby(["District","neighbourhood"]).agg({
    "number_of_reviews":"sum","id":"count"}).reset_index()

# %%
rev_april_21["rev/locations"] = rev_april_21["number_of_reviews"]/rev_april_21["id"]

# %%
rev_april_21 = rev_april_21.sort_values("number_of_reviews",ascending=False)

# %%
rev_april_21 = rev_april_21.set_index(["District","neighbourhood"])

# %%
rev_april_21.columns
# Out:
# Index(['number_of_reviews', 'id', 'rev/locations'], dtype='object')

# %%
rev_april_21_p1= rev_april_21.drop(columns=[ 'id', 'rev/locations'])

# %%
n_subplots = len(rev_april_21_p1.index.levels[0])
fig, axes = plt.subplots(nrows=1, ncols=n_subplots, sharey=True, figsize=(14, 8))  # width, height
graph = dict(zip(rev_april_21_p1.index.levels[0], axes))
plots = list(map(lambda x: plot_function(x, graph[x],rev_april_21_p1), graph))
ax.tick_params(axis='both', which='both', length=0)
fig.subplots_adjust(wspace=0)
plt.show()

# %%
rev_april_21_p2= rev_april_21.drop(columns=[ 'id', 'number_of_reviews'])

# %%
n_subplots = len(rev_april_21_p2.index.levels[0])
fig, axes = plt.subplots(nrows=1, ncols=n_subplots, sharey=True, figsize=(14, 8))  # width, height
graph = dict(zip(rev_april_21_p1.index.levels[0], axes))
plots = list(map(lambda x: plot_function(x, graph[x],rev_april_21_p2), graph))
ax.tick_params(axis='both', which='both', length=0)
fig.subplots_adjust(wspace=0)
plt.show()

# %% [markdown]
# #### 1.2.3. Are there more types of room in one neihbourhood than the other and in Amstertdam?

# %%
#we could think the center has more.....
listings_april_21_type= listings_april_21.loc[(listings_april_21["room_type"] == "Entire home/apt") | (listings_april_21["room_type"] == "Private room")]

# %%
listings_april_21_type_ams = listings_april_21_type.groupby(["room_type"])["id"].count().reset_index()

# %%
fig, ax = plt.subplots(1,1,figsize = (12,8),sharex=True)

fig.suptitle('Types of rentings in Amsterdam', size='20', fontweight='bold')


data= listings_april_21_type_ams

sns.barplot(x = "room_type",y = "id", ax = ax, data=data)
ax.set_ylabel("number of locations")
plt.xticks(rotation=45)
plt.tight_layout()

# %%
listings_april_21_type_district = listings_april_21_type.groupby(["District","room_type"])["id"].count().reset_index()
listings_april_21_type_district
# Out:
#       District        room_type    id
# 0      Centrum  Entire home/apt  2399
# 1      Centrum     Private room  1023
# 2   Nieuw-West  Entire home/apt   533
# 3   Nieuw-West     Private room   295
# 4        Noord  Entire home/apt   858
# 5        Noord     Private room   314
# 6         Oost  Entire home/apt  2384
# 7         Oost     Private room   520
# 8         West  Entire home/apt  4488
# 9         West     Private room   778
# 10        Zuid  Entire home/apt  3095
# 11        Zuid     Private room   653
# 12    Zuidoost  Entire home/apt   139
# 13    Zuidoost     Private room   173

# %%
#plt.style.use('fivethirtyeight')
fig, ax = plt.subplots(1,1,figsize = (12,8),sharex=True)

fig.suptitle('Location x district', size='20', fontweight='bold')


data= listings_april_21_type_district

sns.barplot(x = "District",y = "id", ax = ax, data=data,hue="room_type")
ax.set_ylabel("number of locations")
plt.xticks(rotation=45)
plt.tight_layout()

plt.savefig("../figures/type_locations_x_district.png",dpi=600)
plt.show()

# %%
#not clear the meaning

# %%
dummies = pd.get_dummies(listings_april_21["room_type"])

# %%
one_hot = pd.concat([listings_april_21,dummies], axis=1)

# %%
#total number of reviews will will use it as an indicator
april_21_x_district = one_hot.groupby(["District"]).agg({"number_of_reviews":"sum","id":"count",
                                                       "price":"median","Entire home/apt":"sum",
                                                       "Private room":"sum"}).reset_index()

april_21_x_district
# Out:
#      District  number_of_reviews    id   price  Entire home/apt  Private room
# 0     Centrum             130369  3472  126.00           2399.0        1023.0
# 1  Nieuw-West              19628   840   84.00            533.0         295.0
# 2       Noord              29690  1198  100.80            858.0         314.0
# 3        Oost              54226  2924  105.00           2384.0         520.0
# 4        West             105849  5298  105.00           4488.0         778.0
# 5        Zuid              78519  3774  115.92           3095.0         653.0
# 6    Zuidoost               8679   319   67.20            139.0         173.0

# %%
april_21_x_district.corr()
# Out:
#                    number_of_reviews        id     price  Entire home/apt  \
# number_of_reviews           1.000000  0.873232  0.857302         0.814671
# id                          0.873232  1.000000  0.741924         0.993870
# price                       0.857302  0.741924  1.000000         0.684857
# Entire home/apt             0.814671  0.993870  0.684857         1.000000
# Private room                0.994384  0.841989  0.877365         0.777208
#
#                    Private room
# number_of_reviews      0.994384
# id                     0.841989
# price                  0.877365
# Entire home/apt        0.777208
# Private room           1.000000

# %% [markdown]
# #### 1.2.4. How are the neighbourhoods according to the desciptors?

# %%
descp_x_district= listings_with_descriptors.groupby("District").agg({"average_number_of_crimes":"mean","green_areas_m2":"mean",
                                                   "num_green_areas":"mean"}).reset_index()

descp_x_district
# Out:
#      District  average_number_of_crimes  green_areas_m2  num_green_areas
# 0     Centrum                   1701.00           82263               10
# 1  Nieuw-West                   1373.34         5836543               46
# 2       Noord                    804.34         2726583               15
# 3        Oost                   1064.67         1827890               22
# 4        West                   1089.34          541141               10
# 5        Zuid                   1064.00         1819623               11
# 6    Zuidoost                   1228.00         5082510                6

# %%
fig, ax = plt.subplots(1,3,figsize = (12,8),sharex=True)

#fig.suptitle('Description of the neighbourhoods according to the descriptors used', size='20', fontweight='bold')

ax[0].set_title('Average total crimes per district', size='10', fontweight='bold')

sns.barplot(x = descp_x_district['District'],y = descp_x_district['average_number_of_crimes'], ax = ax[0])

plt.sca(ax[0])
plt.xticks(rotation=45)
plt.tight_layout()



ax[1].set_title('Total of green area per district ', size='10', fontweight='bold')

sns.barplot(x = descp_x_district['District'],y = descp_x_district['green_areas_m2'],ax = ax[1])
plt.sca(ax[1])
plt.xticks(rotation=45)
plt.tight_layout()

ax[2].set_title('Number of green areas per district ', size='10', fontweight='bold')

sns.barplot(x = descp_x_district['District'],y = descp_x_district['num_green_areas'], ax = ax[2])
plt.sca(ax[2])
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("../figures/descriptors_x_district.png",dpi=600)

plt.show()

# %% [markdown]
# ### 1.3. We expect to find more locations and bookings where there are more green areas and less criminality.

# %% [markdown]
# #### 1.3.1. Is the number of listings and bookings per neihbourhood correlated to the green areas and the number of crimes?

# %%
#We expect to find more bookings where there are more green areas and less criminality.
#We expect to find more locations where there are more green areas and less criminality.

# %%
listings_with_descriptors.head()
# Out:
#       id                           neighbourhood   latitude  longitude  \
# 0   2818  Oostelijk Havengebied - Indische Buurt  52.365755   4.941419
# 1   3209                              Westerpark  52.390225   4.873924
# 2  20168                            Centrum-Oost  52.365087   4.893541
# 3  25428                            Centrum-West  52.373114   4.883668
# 4  27886                            Centrum-West  52.386727   4.892078
#
#          room_type   price  minimum_nights  number_of_reviews  \
# 0     Private room   49.56               3                248
# 1  Entire home/apt  134.40               4                 42
# 2  Entire home/apt   67.20               1                233
# 3  Entire home/apt  105.00              14                  1
# 4     Private room  126.00               2                171
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               2.10                               1                44
# ...

# %%
listings_xy_xd_desc_2 = listings_with_descriptors.groupby(["Date","District"]).agg({"District":"count","number_of_reviews":"mean",
                                                                                  "average_number_of_crimes":"mean",
                                                                                  "green_areas_m2":"mean",
                                                                                  "num_green_areas":"mean",
                                                                                  "price" : "median"
                                                                                 }).rename(columns=
                                                                                        {"District":"total locations"}).reset_index()

# %%
listings_xy_xd_desc_2.head()
# Out:
#          Date    District  total locations  number_of_reviews  \
# 0  April 2020     Centrum             3828          38.786834
# 1  April 2020  Nieuw-West              909          25.063806
# 2  April 2020       Noord             1221          26.129402
# 3  April 2020        Oost             3221          19.734554
# 4  April 2020        West             5812          21.581211
#
#    average_number_of_crimes  green_areas_m2  num_green_areas  price
# 0                   1701.00           82263               10  134.4
# 1                   1373.34         5836543               46   84.0
# 2                    804.34         2726583               15  105.0
# 3                   1064.67         1827890               22  105.0
# 4                   1089.34          541141               10  105.0

# %%
listings_xy_xd_desc_corr_2 = listings_xy_xd_desc_2.corr()
listings_xy_xd_desc_corr_2
# Out:
#                           total locations  number_of_reviews  \
# total locations                  1.000000          -0.153952
# number_of_reviews               -0.153952           1.000000
# average_number_of_crimes         0.051620           0.723392
# green_areas_m2                  -0.858208          -0.145862
# num_green_areas                 -0.354978          -0.198651
# price                            0.708069           0.249250
#
#                           average_number_of_crimes  green_areas_m2  \
# total locations                           0.051620       -0.858208
# number_of_reviews                         0.723392       -0.145862
# average_number_of_crimes                  1.000000       -0.066017
# green_areas_m2                           -0.066017        1.000000
# num_green_areas                           0.125145        0.554749
# price                                     0.184790       -0.858414
#
#                           num_green_areas     price
# ...

# %%
plt.figure(figsize=(16, 6))
# define the mask to set the values in the upper triangle to True
mask = np.triu(np.ones_like(listings_xy_xd_desc_corr_2, dtype=bool))
heatmap = sns.heatmap(listings_xy_xd_desc_corr_2, mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':18}, pad=16)
plt.savefig("../figures/descriptors_price_reviews_list_corr.png",dpi=600);

# %%
#It seems to be a strong negative correlation between the number of locations and the total m2 of green space
#It is not what I have expected...
#More green areas, less space for buildings or place of residence/dwelling, therefore less booking as well.
#the number of locations is related with the bookings as well, the more locations more booking as we saw before

# %%
#it seems that our rev/locations, plane booking have a posirive relationship with the number of crimes
#The more crimes the more reviews.... what it makes sense

# %% [markdown]
# ## 2. Compare how the available locations have change during this period (number of locations available, type of locations...)

# %% [markdown]
# ### 2.1. A decrease of locations availability for the corona period

# %% [markdown]
# #### 2.1.2 Number of locations per date

# %%
# Number of locations per date
num_loc_x_date = listings_with_descriptors["Date"].value_counts()
num_loc_x_date
# Out:
# December 2018    20030
# April 2020       19362
# December 2020    18522
# April 2021       17825
# Name: Date, dtype: int64

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots(1,1,figsize = (10,6))
sns.barplot(x= num_loc_x_date.index,y=num_loc_x_date)
plt.title("Total amount of locations per date",fontsize=20, fontweight='bold')
ax.set_ylabel("total number of locations")

for index,data in enumerate(num_loc_x_date.values):
    plt.text(x=index , y =data , s=f"{data}" , fontdict=dict(fontsize=13))
plt.savefig("../figures/locations_x_year.png",dpi=500)
    
plt.show()

# %% [markdown]
# #### 2.1.2 Number of locations per district per date

# %%
num_loc_x_district =listings_with_descriptors.groupby(["Date"])["District"].value_counts().rename('count').reset_index()
num_loc_x_district
# Out:
#              Date    District  count
# 0      April 2020        West   5812
# 1      April 2020        Zuid   4037
# 2      April 2020     Centrum   3828
# 3      April 2020        Oost   3221
# 4      April 2020       Noord   1221
# 5      April 2020  Nieuw-West    909
# 6      April 2020    Zuidoost    334
# 7      April 2021        West   5298
# 8      April 2021        Zuid   3774
# 9      April 2021     Centrum   3472
# 10     April 2021        Oost   2924
# 11     April 2021       Noord   1198
# 12     April 2021  Nieuw-West    840
# 13     April 2021    Zuidoost    319
# 14  December 2018        West   6150
# 15  December 2018        Zuid   4196
# 16  December 2018     Centrum   4056
# 17  December 2018        Oost   3245
# 18  December 2018       Noord   1148
# 19  December 2018  Nieuw-West    906
# 20  December 2018    Zuidoost    329
# 21  December 2020        West   5545
# 22  December 2020        Zuid   3887
# 23  December 2020     Centrum   3606
# ...

# %%
num_dec_x_district =num_loc_x_district.loc[(num_loc_x_district["Date"] == "December 2020") | (num_loc_x_district["Date"]=="December 2018")]

# %%
num_april_x_district =num_loc_x_district.loc[(num_loc_x_district["Date"] == "April 2020") | (num_loc_x_district["Date"]=="April 2021")]
num_april_x_district
# Out:
#           Date    District  count
# 0   April 2020        West   5812
# 1   April 2020        Zuid   4037
# 2   April 2020     Centrum   3828
# 3   April 2020        Oost   3221
# 4   April 2020       Noord   1221
# 5   April 2020  Nieuw-West    909
# 6   April 2020    Zuidoost    334
# 7   April 2021        West   5298
# 8   April 2021        Zuid   3774
# 9   April 2021     Centrum   3472
# 10  April 2021        Oost   2924
# 11  April 2021       Noord   1198
# 12  April 2021  Nieuw-West    840
# 13  April 2021    Zuidoost    319

# %%
sns.set_palette('RdPu_r')
current_palette = sns.color_palette()
sns.palplot(current_palette)
plt.show()

# %%
#palette_alive = {"yes": "C5", "no": "C0"} #links to palettes
sns.set_style("whitegrid")
fig, ax = plt.subplots(1,2,figsize = (12,8),sharex=True)
fig.suptitle('Comparation of number of locations x district', size='20', fontweight='bold')
ax[0].set_title('Locations x district December', size='15', fontweight='bold')
#hue- by year
sns.barplot(x = num_dec_x_district ['District'],y = num_dec_x_district['count'],
            hue = num_dec_x_district['Date'], ax = ax[0])
plt.sca(ax[0])
plt.xticks(rotation=45)
plt.tight_layout()



ax[1].set_title('Locations x district April', size='15', fontweight='bold')
#hue- by year
sns.barplot(x = num_april_x_district ['District'],y = num_april_x_district['count'],
            hue = num_april_x_district['Date'], ax = ax[1])
plt.sca(ax[1])
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("../figures/locations_x_year_x_district.png",dpi=600)
plt.show()

#b2 plots, one for april one for december

# %% [markdown]
# In general we see a decrease from December 2018 to 2020 of number of listings in almost all the neighbourhoods.
# Noord, Nieuw West and Zuidoost are less popular neihbourhoods and further from the city. Those seem that did not change so much.

# %%
#We will have to see if those differences are significant

# %%
#noord moviemineto de centrificacion, en contra de toda las tendencia que vemos en todos

# %% [markdown]
# ### 2.2. We expect less accommodations available

# %% [markdown]
# #### 2.2.1. Locations availability per date x type of room

# %%
priv_entire = listings.loc[(listings["room_type"] == "Entire home/apt")|(listings["room_type"] == "Private room")]

# %%
priv_entire['room_type'].value_counts()
# Out:
# Entire home/apt    59313
# Private room       15673
# Name: room_type, dtype: int64

# %%
#Number of locations per date and room type
priv_entire_listings = priv_entire.groupby(["Date"])['room_type'].value_counts().rename("num_locations").reset_index()
priv_entire_listings
# Out:
#             Date        room_type  num_locations
# 0     April 2020  Entire home/apt          15095
# 1     April 2020     Private room           3945
# 2     April 2021  Entire home/apt          13896
# 3     April 2021     Private room           3756
# 4  December 2018  Entire home/apt          15889
# 5  December 2018     Private room           4076
# 6  December 2020  Entire home/apt          14433
# 7  December 2020     Private room           3896

# %%
priv_entire_listings_dec=priv_entire_listings.loc[(priv_entire_listings["Date"] == "December 2020") | (priv_entire_listings["Date"]=="December 2018")]
priv_entire_listings_april =priv_entire_listings.loc[(priv_entire_listings["Date"] == "April 2020") | (priv_entire_listings["Date"]=="April 2021")]

# %%
sns.set_palette('RdPu_r')
fig, ax = plt.subplots(1,2,figsize = (12,10),sharey=True)
fig.suptitle('Comparation locations x type of accomodation', size='20', fontweight='bold')
ax[0].set_title('Locations x type December', size='15', fontweight='bold')
#hue- by year
sns.barplot(x = priv_entire_listings_dec['room_type'],y = priv_entire_listings_dec ['num_locations'],
            hue = priv_entire_listings_dec['Date'], ax = ax[0])
plt.sca(ax[0])
plt.xticks(rotation=45)
plt.tight_layout()
ax[0].set_yscale('log')


ax[1].set_title('Locations x type April', size='15', fontweight='bold')
#hue- by year
sns.barplot(x = priv_entire_listings_april  ['room_type'],y = priv_entire_listings_april['num_locations'],
            hue = priv_entire_listings_april ['Date'], ax = ax[1])
plt.sca(ax[1])
plt.xticks(rotation=45)
plt.tight_layout()

# plt.savefig("../figures/type_of_accomodation.png",dpi=600)
#logarithm scale
ax[1].set_yscale('log')
plt.show()

# %% [markdown]
# ### 2.3. We expect more fuller house renting than rooms

# %% [markdown]
# Are there more bookings by date or room type more then another?

# %%
date_room_reviews = priv_entire.groupby(["Date","room_type"])["number_of_reviews"].sum().reset_index()
date_room_reviews
# Out:
#             Date        room_type  number_of_reviews
# 0     April 2020  Entire home/apt             241811
# 1     April 2020     Private room             234756
# 2     April 2021  Entire home/apt             212772
# 3     April 2021     Private room             205200
# 4  December 2018  Entire home/apt             231455
# 5  December 2018     Private room             198459
# 6  December 2020  Entire home/apt             225952
# 7  December 2020     Private room             216605

# %%
date_room_reviews_dec=date_room_reviews.loc[(date_room_reviews["Date"] == "December 2020") | (date_room_reviews["Date"]=="December 2018")]
date_room_reviews_april =date_room_reviews.loc[(date_room_reviews["Date"] == "April 2020") | (date_room_reviews["Date"]=="April 2021")]

# %%
sns.set_palette('RdPu_r')
fig, ax = plt.subplots(1,2,figsize = (12,10),sharey=True)
fig.suptitle('Comparation bookings x type of accomodation', size='20', fontweight='bold')
ax[0].set_title('Bookings x type December', size='15', fontweight='bold')
#hue- by year
sns.barplot(x = date_room_reviews_dec['room_type'],y = date_room_reviews_dec ['number_of_reviews'],
            hue = date_room_reviews_dec['Date'], ax = ax[0])
plt.sca(ax[0])
plt.xticks(rotation=45)
plt.tight_layout()



ax[1].set_title('Bookings x type April', size='15', fontweight='bold')
#hue- by year
sns.barplot(x = date_room_reviews_april  ['room_type'],y = date_room_reviews_april['number_of_reviews'],
            hue = date_room_reviews_april ['Date'], ax = ax[1])
plt.sca(ax[1])
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("../figures/reviews_x_Date_x_type.png",dpi=600)

plt.show()

# %% [markdown]
# ### 2.4. An impact on the price between pandemic and pre pandemic

# %% [markdown]
# #### 2.4.1. Distribution of price

# %%
listings["price"].describe()
# Out:
# count    75739.000000
# mean       131.587028
# std        146.879768
# min          0.000000
# 25%         79.800000
# 50%        108.360000
# 75%        151.200000
# max       7560.000000
# Name: price, dtype: float64

# %%
#IQR=Q3 −  Q1
#whiskers = Q3 + 1.5*IQR
# whiskers_price = 
iqr_price = listings["price"].describe()[6] - listings["price"].describe()[4]
whisker_upper = listings["price"].describe()[6]  + 1.5*iqr_price
whisker_lower =listings["price"].describe()[4]  - 1.5*iqr_price  
#over this amount I can consider outlier, The lower is 0 as it can not be negative

# %%
price_260=listings.loc[listings["price"] < 260]

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots(1,1,figsize = (12,6))

#take big prices out, the 75q is arround 160-160

sns.histplot(price_260["price"])
ax.set_title("Distribution of average price in the last year price", fontsize=15,fontweight='semibold')
plt.show()

# %% [markdown]
# #### 2.4.2. Average price per date

# %%
listings.groupby(["Date"]).describe()["price"]
#we can see that there are really big differences between the price per nights
#maybe is good to discard the really high prices and look at the rest of the data
# Out:
#                  count        mean         std  min    25%     50%     75%  \
# Date
# April 2020     19362.0  139.270022  195.807925  0.0  83.16  112.56  158.76
# April 2021     17825.0  129.776536  129.496555  0.0  79.80  108.36  151.20
# December 2018  20030.0  127.832190  122.496340  0.0  80.64  105.00  147.00
# December 2020  18522.0  129.358503  125.264411  0.0  78.96  107.52  151.20
#
#                   max
# Date
# April 2020     7560.0
# April 2021     6720.0
# December 2018  7140.0
# December 2020  6720.0

# %%
#plt.style.use('fivethirtyeight')
fig, ax = plt.subplots(1,1,figsize = (12,8),sharex=True)

fig.suptitle('Comparation of average price x date', size='20', fontweight='bold')

#The whiskers of the whole distribution of the variable price, sets the limit of outlier at 260
data= listings.loc[listings["price"] < 260]

sns.boxplot(x = "Date",y = "price", ax = ax, data=data)
ax.set_ylabel("price in euros")
plt.xticks(rotation=45)
plt.tight_layout()




plt.show()
#we don´t see differnces we have to look at the data set where we have all the information about daily prices
#of all locations
###la cola es larga, fuera del whisker
#test de hypothesis propuesto: o anova o pair by pair, o test 2 by 2 combinations

# %%
#lots of outliers, the average price is above the median. The median gives us a more accurate information.
#the midian price for all periods is around 100 euros

#we could test here to see if those values are significaitavly differents

#Are all the means equal? A computation called ANOVA (analysis of variance) answers this question.
#If ANOVA shows that the means aren’t all equal, then which means are unequal, and by how much?
#There are many ways to answer this question (and they give different answers), but we’ll use
#a process called Tukey’s HSD (Honestly Significant Difference).

# %% [markdown]
# #### 2.4.3. Average price district

# %%
listings.groupby(["Date","District"])["price"].median()
# Out:
# Date           District
# April 2020     Centrum       134.40
#                Nieuw-West     84.00
#                Noord         105.00
#                Oost          105.00
#                West          105.00
#                Zuid          121.80
#                Zuidoost       64.26
# April 2021     Centrum       126.00
#                Nieuw-West     84.00
#                Noord         100.80
#                Oost          105.00
#                West          105.00
#                Zuid          115.92
#                Zuidoost       67.20
# December 2018  Centrum       126.00
#                Nieuw-West     82.32
#                Noord          95.76
#                Oost          100.80
#                West          100.80
#                Zuid          109.20
#                Zuidoost       63.00
# December 2020  Centrum       122.64
#                Nieuw-West     84.00
#                Noord         100.80
#                Oost          105.00
# ...

# %%
plt.style.use('fivethirtyeight')
sns.set_style("whitegrid")
fig, ax = plt.subplots(1,1,figsize = (12,8),sharex=True)

fig.suptitle('Comparation of average price x district', size='20', fontweight='bold')

#we take 200 as the 75quartile of the whole data set is around 160
data= listings.loc[listings["price"] < 200]

sns.boxplot(x = "District",y = "price", ax = ax, data=data)
plt.hlines(y=100.800000 ,xmin=0, xmax=1,linewidth=4, color='r')
ax.set_ylabel("price in euros")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("../figures/avg_price_x_district.png",dpi=600)

plt.show()

# %%
listings.groupby(["District","Date"])["price"].describe()
# Out:
#                            count        mean         std    min     25%  \
# District   Date
# Centrum    April 2020     3828.0  189.353292  378.025661  11.76  100.80
#            April 2021     3472.0  151.029194  159.489582   0.00   84.00
#            December 2018  4056.0  159.338018  133.427599  11.76   99.96
#            December 2020  3606.0  150.027820  163.338357   0.00   84.00
# Nieuw-West April 2020      909.0  104.780066   85.577958  21.84   58.80
#            April 2021      840.0  105.535000   94.480760  16.80   58.80
#            December 2018   906.0   97.500265   72.547094  16.80   58.80
#            December 2020   884.0  102.134118   85.938430  16.80   58.80
# Noord      April 2020     1221.0  124.551155  136.205542   8.40   75.60
#            April 2021     1198.0  119.071052   85.230178   0.00   71.40
#            December 2018  1148.0  116.329024  133.969090  10.08   67.20
#            December 2020  1229.0  121.295590  135.955754  14.28   71.40
# ...

# %%
listings.loc[listings["price"] < 200]["price"].describe()
# Out:
# count    66030.000000
# mean       104.758177
# std         38.514737
# min          0.000000
# 25%         75.600000
# 50%        100.800000
# 75%        126.000000
# max        199.920000
# Name: price, dtype: float64

# %% [markdown]
# #### 2.4.4. Average price x date x district

# %%
listings.groupby(["District","Date"]).describe()["price"]
# Out:
#                            count        mean         std    min     25%  \
# District   Date
# Centrum    April 2020     3828.0  189.353292  378.025661  11.76  100.80
#            April 2021     3472.0  151.029194  159.489582   0.00   84.00
#            December 2018  4056.0  159.338018  133.427599  11.76   99.96
#            December 2020  3606.0  150.027820  163.338357   0.00   84.00
# Nieuw-West April 2020      909.0  104.780066   85.577958  21.84   58.80
#            April 2021      840.0  105.535000   94.480760  16.80   58.80
#            December 2018   906.0   97.500265   72.547094  16.80   58.80
#            December 2020   884.0  102.134118   85.938430  16.80   58.80
# Noord      April 2020     1221.0  124.551155  136.205542   8.40   75.60
#            April 2021     1198.0  119.071052   85.230178   0.00   71.40
#            December 2018  1148.0  116.329024  133.969090  10.08   67.20
#            December 2020  1229.0  121.295590  135.955754  14.28   71.40
# ...

# %%
#plt.style.use('fivethirtyeight')
sns.set_style("whitegrid")
fig, ax = plt.subplots(1,2,figsize = (12,8),sharex=True)

fig.suptitle('Comparation of average price x date', size='20', fontweight='bold')

data1= listings.loc[(listings["price"] < 200)& ((listings["Date"]=="December 2018")|
                                                (listings["Date"]=="December 2020"))]

ax[0].set_title('Locations x district December', size='15', fontweight='bold')
ax[0].set_ylabel("price in euros")
sns.boxplot(x = "District",y = "price",data=data1,hue="Date",ax = ax[0])

plt.sca(ax[0])
plt.xticks(rotation=45)
plt.tight_layout()
plt.legend(loc='lower right')

data2= listings.loc[(listings["price"] < 200)& ((listings["Date"]=="April 2020")|
                                                (listings["Date"]=="April 2021"))]


ax[1].set_title('Locations x district April', size='15', fontweight='bold')
sns.boxplot(x = "District",y = "price", data=data2,hue="Date", ax = ax[1])
ax[1].set_ylabel("price in euros")
plt.sca(ax[1])
plt.xticks(rotation=45)
plt.tight_layout()
plt.legend(loc='lower right')
plt.savefig("../figures/price_x_district_x_date.png",dpi=600)
plt.show()

# %%
#It seems that for some neihbourhood the prices have decreased

# %% [markdown]
# ## 3. Analyse the changes on prices, availability and bookings during corona period

# %% [markdown]
# ### 3.1. Prepare the data

# %%
calendar_cor = pd.read_csv("../data/clean_data/calendar_0320_0721.csv")

# %%
calendar_cor.columns
calendar_cor = calendar_cor.drop(columns=['Unnamed: 0', "adjusted_price","minimum_nights","maximum_nights"],axis=1)

# %%
calendar_pre_cor = pd.read_csv("../data/clean_data/calendar_1218_1219.csv")
calendar_pre_cor = calendar_pre_cor.drop(columns='Unnamed: 0',axis=1)
calendar_pre_cor
# Out:
#          listing_id        date available   price  year  month  day  \
# 0              2818  2019-12-05         f   52.00  2019     12    5
# 1             73208  2019-08-30         f  184.80  2019      8   30
# 2             73208  2019-08-29         f  184.80  2019      8   29
# 3             73208  2019-08-28         f  184.80  2019      8   28
# 4             73208  2019-08-27         f  184.80  2019      8   27
# ...             ...         ...       ...     ...   ...    ...  ...
# 3900385    29979667  2018-12-11         t  116.76  2018     12   11
# 3900386    29979667  2018-12-10         t  116.76  2018     12   10
# 3900387    29979667  2018-12-09         t  116.76  2018     12    9
# 3900388    29979667  2018-12-08         t  116.76  2018     12    8
# 3900389    29979667  2018-12-07         t  116.76  2018     12    7
#
#         day_of_week
# 0          Thursday
# 1            Friday
# 2          Thursday
# 3         Wednesday
# 4           Tuesday
# ...             ...
# ...

# %%
##put together the two periods
calendar = pd.concat([calendar_pre_cor,calendar_cor], axis=0)

# %%
#We add reviews as an indicator of booking, every review is an entry with its date
reviews = pd.read_csv("../data/clean_data/reviews.csv")

# %%
#we create a column that says that this day we had a review
reviews["reviewed"] = 1

# %%
#select the columns of interest
reviews = reviews[["listing_id","date","reviewed"]]

# %%
#we need to merge our data sets to have info about prices and review over the time
# we will fill the non review days in the calendar data set with a 0 (with the merge there is a Nan,
#as there is no review for that day and listing)
#we have all this infomation for all the listings
#really large data set
calendar_reviews = calendar.merge(reviews, how='left', left_on=["listing_id", "date"], right_on=["listing_id", "date"]).fillna(0)
calendar_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13298845 entries, 0 to 13298844
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   listing_id   int64
#  1   date         object
#  2   available    object
#  3   price        float64
#  4   year         int64
#  5   month        int64
#  6   day          int64
#  7   day_of_week  object
#  8   reviewed     float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 1014.6+ MB

# %%
calendar_reviews["date"].min()
# Out:
# '2018-12-06'

# %%
calendar_reviews["date"].max()
#between '2018-12-06' and 2021-07-26'
# Out:
# '2021-07-26'

# %%
# Add information about the type of room

# %%
#We just need the information about the listing once, we will drop duplicates and keep the first entry per
#listing
test_subset = listings.drop_duplicates(subset="id",keep="first")
test_subset = test_subset[['id','room_type','calculated_host_listings_count', 'availability_365']]
calendar_reviews=  calendar_reviews.merge(test_subset, how='left', left_on=["listing_id"], right_on=["id"])

# %%
# calendar_reviews_drop = calendar_reviews.drop(columns="id")
# calendar_reviews_drop.info()

# %%
#the nulls are for the listing that we don't have this information
calendar_reviews.isnull().sum()
# Out:
# listing_id                             0
# date                                   0
# available                              0
# price                                  0
# year                                   0
# month                                  0
# day                                    0
# day_of_week                            0
# reviewed                               0
# id                                148917
# room_type                         148917
# calculated_host_listings_count    148917
# availability_365                  148917
# dtype: int64

# %%
calendar_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13298845 entries, 0 to 13298844
# Data columns (total 13 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   listing_id                      int64
#  1   date                            object
#  2   available                       object
#  3   price                           float64
#  4   year                            int64
#  5   month                           int64
#  6   day                             int64
#  7   day_of_week                     object
#  8   reviewed                        float64
#  9   id                              float64
#  10  room_type                       object
#  11  calculated_host_listings_count  float64
#  12  availability_365                float64
# dtypes: float64(5), int64(4), object(4)
# memory usage: 1.4+ GB

# %%
#transform the variable date to datetime variable
calendar_reviews["date"] = pd.to_datetime(calendar_reviews["date"])

# %% [markdown]
# ### 3.2. Price per type of rental

# %%
calendar_reviews.head()
# Out:
#    listing_id       date available  price  year  month  day day_of_week  \
# 0        2818 2019-12-05         f   52.0  2019     12    5    Thursday
# 1       73208 2019-08-30         f  184.8  2019      8   30      Friday
# 2       73208 2019-08-29         f  184.8  2019      8   29    Thursday
# 3       73208 2019-08-28         f  184.8  2019      8   28   Wednesday
# 4       73208 2019-08-27         f  184.8  2019      8   27     Tuesday
#
#    reviewed       id        room_type  calculated_host_listings_count  \
# 0       0.0   2818.0     Private room                             1.0
# 1       0.0  73208.0  Entire home/apt                             1.0
# 2       0.0  73208.0  Entire home/apt                             1.0
# 3       0.0  73208.0  Entire home/apt                             1.0
# 4       0.0  73208.0  Entire home/apt                             1.0
#
#    availability_365
# 0              44.0
# 1               3.0
# 2               3.0
# 3               3.0
# ...

# %%
#I just want to look at the one

# %%
data = calendar_reviews[(np.isin(calendar_reviews['room_type'],['Private room','Entire home/apt']) == True )]

# %%
data2= calendar_reviews[(np.isin(calendar_reviews['room_type'],['Private room','Entire home/apt']) == True )
                       & (calendar_reviews['reviewed'] == 1)]

data2 = data2.groupby(["date","room_type"])["price"].median().rename("daily_median_price").reset_index()

# %%
data = data.groupby(["date","room_type"])["price"].median().rename("daily_median_price").reset_index()

# %%
sns.set_palette(sns.color_palette("tab10"))
sns.set_style("whitegrid")
fig,ax = plt.subplots(figsize = (20,5))
ax.set_title('Evolution of the median price per type of room', size='15', fontweight='bold')
sns.lineplot(x="date",y="daily_median_price", data=data,hue='room_type')
plt.axvline(pd.to_datetime('2020-03-15'), color='r', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-07-01'), color='b', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-08-18'), color='orange', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-12-15'), color='r', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2021-04-20'), color='b', linestyle='--', lw=2)
# plt.savefig("../figures/price_x_type_room.png",dpi=600)
plt.show();

# %%
#interestingly entire appartment had a higher decrease on the prices after corona time
#there is a peak just after the first realease of the measures
#The prices after corona of private rooms have a higher variability than for entire rooms

# %%
#just for the one have been rented for sure because somebody left a review
#Intersting to see the differences
sns.set_palette(sns.color_palette("tab10"))
sns.set_style("whitegrid")
fig,ax = plt.subplots(figsize = (20,5))
ax.set_title('Evolution of the median price per type of room', size='15', fontweight='bold')
sns.lineplot(x="date",y="daily_median_price", data=data2,hue='room_type')
plt.axvline(pd.to_datetime('2020-03-15'), color='r', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-07-01'), color='b', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-08-18'), color='orange', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-12-15'), color='r', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2021-04-20'), color='b', linestyle='--', lw=2)
plt.show()

# %%
# It seems that the appartment that have been booked

# %%
sns.set_palette(sns.color_palette("tab10"))
sns.set_style("whitegrid")
fig,ax = plt.subplots(figsize = (20,5))
ax.set_title('Evolution of the median price per type of room', size='15', fontweight='bold')
sns.lineplot(x="date",y="daily_median_price", data=data2)
plt.axvline(pd.to_datetime('2020-03-15'), color='r', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-07-01'), color='b', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-08-18'), color='orange', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-12-15'), color='r', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2021-04-20'), color='b', linestyle='--', lw=2)
plt.show()

# %%
data2 = data2.set_index("date")

# %%
data2_m= data2.resample('M').mean()

# %%
# Start and end of the date range to extract
start, end = '2018-12-06', '2021-12'
# Plot daily and weekly resampled time series together
fig, ax = plt.subplots(figsize = (20,5))
ax.plot(data2.loc[start:end, 'daily_median_price'],
marker='.', linestyle='-', linewidth=0.5, label='daily_median_price')
ax.plot(data2_m.loc[start:end, 'daily_median_price'],
marker='o', markersize=8, linestyle='-', label='monthly_median_price"')
ax.set_ylabel("price")
ax.legend('')
plt.axvline(pd.to_datetime('2020-03-15'), color='r', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-07-01'), color='b', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-08-18'), color='orange', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-12-15'), color='r', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2021-04-20'), color='b', linestyle='--', lw=2);

#it seem people pays more after the lockdowns... it can be the bias that people just put more rewviews....

# %% [markdown]
# ### 3.3. Weekend no weekend, booked rentals

# %%
calendar_reviews.head()
# Out:
#    listing_id       date available  price  year  month  day day_of_week  \
# 0        2818 2019-12-05         f   52.0  2019     12    5    Thursday
# 1       73208 2019-08-30         f  184.8  2019      8   30      Friday
# 2       73208 2019-08-29         f  184.8  2019      8   29    Thursday
# 3       73208 2019-08-28         f  184.8  2019      8   28   Wednesday
# 4       73208 2019-08-27         f  184.8  2019      8   27     Tuesday
#
#    reviewed        room_type
# 0       0.0     Private room
# 1       0.0  Entire home/apt
# 2       0.0  Entire home/apt
# 3       0.0  Entire home/apt
# 4       0.0  Entire home/apt

# %%
calendar_reviews_corona_booked =calendar_reviews[(calendar_reviews['date'] > pd.to_datetime('2020-03-15')) 
        & ( np.isin(calendar_reviews['day_of_week'],['Friday','Saturday','Sunday']) == True)
         & (np.isin(calendar_reviews['room_type'],['Private room','Entire home/apt']) == True ) 
        &  (calendar_reviews['reviewed'] == 1) ]
    
                
# we just want the one that for sure where rented, that is why we filter by reviewed 1

# %%
calendar_reviews_corona_booked.head()
# Out:
#          listing_id       date available   price  year  month  day  \
# 3900587       20168 2020-03-27         f  104.16  2020      3   27
# 3900588       20168 2020-03-28         f  104.16  2020      3   28
# 3900594       20168 2020-04-03         f  151.20  2020      4    3
# 3901594      255809 2020-06-06         t  147.00  2020      6    6
# 3901763       28871 2020-07-03         f   63.00  2020      7    3
#
#         day_of_week  reviewed        room_type
# 3900587      Friday       1.0  Entire home/apt
# 3900588    Saturday       1.0  Entire home/apt
# 3900594      Friday       1.0  Entire home/apt
# 3901594    Saturday       1.0     Private room
# 3901763      Friday       1.0     Private room

# %%
calendar_reviews_corona_booked = calendar_reviews_corona_booked.groupby(["date","day_of_week","room_type"])\
      .agg({"price":"median","reviewed":"sum"}).reset_index()



calendar_reviews_corona_booked.rename(columns ={'price':'median_price','reviewed':'number_of_reviews'},inplace=True)
# calendar_reviews_corona_booked.columns = ['date', 'day_of_week', 'room_type', 'median_price', 'number_of_reviews']
calendar_reviews_corona_booked.head()
# Out:
#         date day_of_week        room_type  median_price  number_of_reviews
# 0 2020-03-16      Monday  Entire home/apt        109.20               63.0
# 1 2020-03-16      Monday     Private room         63.00               87.0
# 2 2020-03-17     Tuesday  Entire home/apt         96.60               22.0
# 3 2020-03-17     Tuesday     Private room         68.04               39.0
# 4 2020-03-18   Wednesday  Entire home/apt         98.70               26.0

# %%
calendar_reviews_corona_booked.groupby("room_type")['median_price'].median().reset_index()
# Out:
#          room_type  median_price
# 0  Entire home/apt         130.2
# 1     Private room          92.4

# %%
calendar_reviews_corona_booked.groupby(["day_of_week",'room_type'])['median_price'].describe()[["min","max","50%"]]
# Out:
#                                min     max     50%
# day_of_week room_type
# Friday      Entire home/apt  98.28  249.90  132.72
#             Private room     57.12  194.88   92.40
# Saturday    Entire home/apt  61.32  230.58  126.00
#             Private room     63.00  158.76   92.19
# Sunday      Entire home/apt  74.76  201.18  134.40
#             Private room     63.00  133.56   92.61

# %%
sns.set_palette(sns.color_palette("tab10"))
sns.set_style("whitegrid")
fig,ax = plt.subplots(figsize = (20,5))
ax.set_title('Median price for weekend days', size='15', fontweight='bold')
sns.lineplot(x="date",y="median_price", data=calendar_reviews_corona_booked,hue='room_type')
plt.axvline(pd.to_datetime('2020-03-15'), color='r', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-07-01'), color='b', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-08-18'), color='orange', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-12-15'), color='r', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2021-04-20'), color='b', linestyle='--', lw=2)
plt.savefig("../figures/weekend_price.png",dpi=600)
plt.show();

# %%
###no weekend

calendar_reviews_corona_booked_week =calendar_reviews[(calendar_reviews['date'] > pd.to_datetime('2020-03-15')) 
        & ( np.isin(calendar_reviews['day_of_week'],['Monday','Tuesday','Wednesday','Thursday']) == True)
         & (np.isin(calendar_reviews['room_type'],['Private room','Entire home/apt']) == True ) 
        &  (calendar_reviews['reviewed'] == 1) ]

# %%
calendar_reviews_corona_booked_week = calendar_reviews_corona_booked_week.groupby(["date","day_of_week","room_type"])\
      .agg({"price":"median","reviewed":"sum"}).reset_index()



calendar_reviews_corona_booked_week.rename(columns ={'price':'median_price','reviewed':'number_of_reviews'},inplace=True)
calendar_reviews_corona_booked_week.head()
# Out:
#         date day_of_week        room_type  median_price  number_of_reviews
# 0 2020-03-16      Monday  Entire home/apt        109.20               63.0
# 1 2020-03-16      Monday     Private room         63.00               87.0
# 2 2020-03-17     Tuesday  Entire home/apt         96.60               22.0
# 3 2020-03-17     Tuesday     Private room         68.04               39.0
# 4 2020-03-18   Wednesday  Entire home/apt         98.70               26.0

# %%
calendar_reviews_corona_booked_week.groupby("room_type")['median_price'].median().reset_index()
# Out:
#          room_type  median_price
# 0  Entire home/apt        128.52
# 1     Private room         84.00

# %%
calendar_reviews_corona_booked_week.groupby(["day_of_week",'room_type'])['median_price'].describe()[["min","max","50%"]]
# Out:
#                                min     max     50%
# day_of_week room_type
# Monday      Entire home/apt  57.96  210.00  132.30
#             Private room     50.40  146.16   84.00
# Thursday    Entire home/apt  65.10  284.76  136.50
#             Private room     33.60  141.12   84.00
# Tuesday     Entire home/apt  78.96  284.76  127.05
#             Private room     44.94  155.40   83.58
# Wednesday   Entire home/apt  73.08  193.20  126.00
#             Private room     56.28  137.76   84.00

# %%
sns.set_palette(sns.color_palette("tab10"))
sns.set_style("whitegrid")
fig,ax = plt.subplots(figsize = (20,5))
ax.set_title('Median price for week days', size='15', fontweight='bold')
sns.lineplot(x="date",y="median_price", data=calendar_reviews_corona_booked_week,hue="room_type")
plt.axvline(pd.to_datetime('2020-03-15'), color='r', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-07-01'), color='b', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-08-18'), color='orange', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-12-15'), color='r', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2021-04-20'), color='b', linestyle='--', lw=2)
plt.savefig("../figures/week_price.png",dpi=600)
plt.show();

# %% [markdown]
# ### 3.4. A fluctuation on the prices during this period should follow a pattern according to the country restrictions of mobility and touristic activities

# %% [markdown]
# #### 3.3.1. Exploring the price

# %%
calendar_reviews["price"].describe().round(2)
# Out:
# count    13298845.00
# mean          142.54
# std           138.91
# min             5.04
# 25%            84.00
# 50%           117.60
# 75%           168.00
# max          9775.92
# Name: price, dtype: float64

# %%
#IQR=Q3 −  Q1
#whiskers = Q3 + 1.5*IQR
# whiskers_price = 
iqr_price = calendar_reviews["price"].describe()[6] - calendar_reviews["price"].describe()[4]
whisker_upper = calendar_reviews["price"].describe()[6]  + 1.5*iqr_price
whisker_lower =calendar_reviews["price"].describe()[4]  - 1.5*iqr_price  
#over this amount I can consider outlier, The lower is 0 as it can not be negative
whisker_upper,whisker_lower
#we should filter the data over 300, those are really unusual prices
# Out:
# (294.0, -42.0)

# %%
calendar_reviews = calendar_reviews.loc[calendar_reviews["price"]<300]

# %% [markdown]
# #### 3.3.2.  Average price per day over the years

# %%
#calendar_reviews.groupby(['month','year']).median()
# Out:
#             listing_id   price  day  reviewed
# month year
# 1     2019    17470838  117.60   16       0.0
#       2021    18650212  113.40   16       0.0
# 2     2019    17460902  117.60   15       0.0
#       2021    18629212  113.40   15       0.0
# 3     2019    17455495  117.60   16       0.0
#       2020    18604324  109.20   22       0.0
#       2021    18647276  113.40   16       0.0
# 4     2019    17446031  118.20   15       0.0
#       2020    18523387  112.56   15       0.0
#       2021    18610618  113.40   15       0.0
# 5     2019    17460902  118.30   16       0.0
#       2020    18517402  113.40   16       0.0
#       2021    18620522  113.40   16       0.0
# 6     2019    17469086  118.70   16       0.0
#       2020    18523760  113.40   15       0.0
#       2021    18622506  113.40   15       0.0
# 7     2019    17469086  118.60   16       0.0
#       2020    18664793  109.20   16       0.0
#       2021    18496295  113.40    5       0.0
# ...

# %%
#how many bookings/reviews x day along time
review_avgprice_xday = calendar_reviews.groupby("date").agg({"reviewed":
                                      "sum","price":"median"}).rename(columns= {"reviewed":
                                                                                "reviews","price":"median_price"}
                                                                     ).reset_index()

# %%
#https://www.dataquest.io/blog/tutorial-time-series-analysis-with-pandas/

# %%
review_avgprice_xday = review_avgprice_xday.set_index("date")
review_avgprice_xday.head()
# Out:
#             reviews  median_price
# date
# 2018-12-06     77.0         120.7
# 2018-12-07     92.0         117.6
# 2018-12-08    117.0         117.6
# 2018-12-09    426.0         117.2
# 2018-12-10    226.0         116.5

# %%
#I compute the average mean x month
review_avgprice_xmonth= review_avgprice_xday.resample('M').mean()

# %%
###no high correlation....
review_avgprice_xday.corr()
# Out:
#                reviews  median_price
# reviews       1.000000      0.464818
# median_price  0.464818      1.000000

# %%
# sns.color_palette("Set2")
# current_palette = sns.color_palette()

# %%
sns.set_palette(sns.color_palette("tab10"))

# %%
#add vertical lines
sns.set_palette(sns.color_palette("tab10"))
sns.set_style("whitegrid")
# ax = review_avgprice_xday.loc['2018-12-06':'2021-12','median_price'].plot( linestyle='-')
# ax.set_ylabel('median price per day(euros)');

# Start and end of the date range to extract
start, end = '2018-12-06', '2021-12'
# Plot daily and weekly resampled time series together
fig, ax = plt.subplots(figsize = (20,5))
ax.plot(review_avgprice_xday.loc[start:end, 'median_price'],
marker='.', linestyle='-', linewidth=0.5, label='Median Daily price')
ax.plot(review_avgprice_xmonth.loc[start:end, 'median_price'],
marker='o', markersize=8, linestyle='-', label='Monthly Median price')
ax.set_ylabel("median price per day(euros)")
plt.axvline(pd.to_datetime('2020-03-15'), color='r', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-07-01'), color='b', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-08-18'), color='orange', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-12-15'), color='r', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2021-04-20'), color='b', linestyle='--', lw=2)
ax.legend();
plt.savefig("../figures/price_over_time.png",dpi=600)

# %% [markdown]
# #### 3.3.3.  Average price per year

# %%
# Start and end of the date range to extract
start, end = '2018-12','2018-12'
# Plot daily and weekly resampled time series together
fig, ax = plt.subplots(figsize = (20,5))
ax.plot(review_avgprice_xday.loc[start:end, 'median_price'],
marker='.', linestyle='-', linewidth=0.5, label='Median Daily price')
ax.plot(review_avgprice_xmonth.loc[start:end, 'median_price'],
marker='o', markersize=8, linestyle='-', label='Monthly Median price')
ax.set_ylabel("median price per day(euros)")
ax.legend();

# %%
# Start and end of the date range to extract
start, end = '2019-01','2019-12'
# Plot daily and weekly resampled time series together
fig, ax = plt.subplots(figsize = (20,5))
ax.plot(review_avgprice_xday.loc[start:end, 'median_price'],
marker='.', linestyle='-', linewidth=0.5, label='Median Daily price')
ax.plot(review_avgprice_xmonth.loc[start:end, 'median_price'],
marker='o', markersize=8, linestyle='-', label='Monthly Median price')
ax.set_ylabel("median price per day(euros)")
ax.legend();

# %%
sns.set_palette(sns.color_palette("tab10"))
sns.set_style("whitegrid")
# Start and end of the date range to extract
start, end = '2020-01','2020-12'
# Plot daily and weekly resampled time series together
fig, ax = plt.subplots(figsize = (20,5))
ax.plot(review_avgprice_xday.loc[start:end, 'median_price'],
marker='.', linestyle='-', linewidth=0.5, label='Median Daily price')
ax.plot(review_avgprice_xmonth.loc[start:end, 'median_price'],
marker='o', markersize=8, linestyle='-', label='Monthly Median price')
ax.set_ylabel("median price per day(euros)")
plt.axvline(pd.to_datetime('2020-03-15'), color='r', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-07-01'), color='b', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-08-18'), color='orange', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-12-15'), color='r', linestyle='--', lw=2)
ax.legend();
plt.savefig("../figures/price_2020.png",dpi=600)

# %%
sns.set_palette(sns.color_palette("tab10"))
sns.set_style("whitegrid")
# Start and end of the date range to extract
start, end = '2021-01', '2021-12'
# Plot daily and weekly resampled time series together
fig, ax = plt.subplots(figsize = (20,5) )
ax.plot(review_avgprice_xday.loc[start:end, 'median_price'],
marker='.', linestyle='-', linewidth=0.5, label='Median Daily price')
ax.plot(review_avgprice_xmonth.loc[start:end, 'median_price'],
marker='o', markersize=8, linestyle='-', label='Monthly Median price')
ax.set_ylabel("median price per day(euros)")
plt.axvline(pd.to_datetime('2021-04-20'), color='b', linestyle='--', lw=2)
ax.legend();

# %% [markdown]
# ### 3.5. A fluctuation on the bookings during this period should follow a pattern according to the country restrictions of mobility and touristic activities

# %%
#how many bookings/reviews x day along time
review_avgprice_xday.head()
# Out:
#             reviews  median_price
# date
# 2018-12-06     77.0         120.7
# 2018-12-07     92.0         117.6
# 2018-12-08    117.0         117.6
# 2018-12-09    426.0         117.2
# 2018-12-10    226.0         116.5

# %%
#add vertical lines
sns.set_palette(sns.color_palette("tab10"))
sns.set_style("whitegrid")
# ax = review_avgprice_xday.loc['2018-12-06':'2021-12','median_price'].plot( linestyle='-')
# ax.set_ylabel('median price per day(euros)');

# Start and end of the date range to extract
start, end = '2018-12-06', '2021-12'
# Plot daily and weekly resampled time series together
fig, ax = plt.subplots(figsize = (20,5))
ax.plot(review_avgprice_xday.loc[start:end, 'reviews'],
marker='.', linestyle='-', linewidth=0.5, label='Number of reviews x day')
ax.plot(review_avgprice_xmonth.loc[start:end, 'reviews'],
marker='o', markersize=8, linestyle='-', label='Number of reviews x day x month')
ax.set_ylabel("total reviews")
ax.legend('')
plt.axvline(pd.to_datetime('2020-03-15'), color='r', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-07-01'), color='b', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-08-18'), color='orange', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-12-15'), color='r', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2021-04-20'), color='b', linestyle='--', lw=2)
plt.savefig("../figures/reviews_over_time.png",dpi=600)

# %%
sns.set_palette(sns.color_palette("tab10"))
sns.set_style("whitegrid")
# Start and end of the date range to extract
start, end = '2020-01','2020-12'
# Plot daily and weekly resampled time series together
fig, ax = plt.subplots(figsize = (20,5))
ax.plot(review_avgprice_xday.loc[start:end, 'reviews'],
marker='.', linestyle='-', linewidth=0.5, label='Number of reviews x day')
ax.plot(review_avgprice_xmonth.loc[start:end, 'reviews'],
marker='o', markersize=8, linestyle='-', label='Number of reviews x day x month')
ax.set_ylabel("total reviews")
plt.axvline(pd.to_datetime('2020-03-15'), color='r', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-07-01'), color='b', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-08-18'), color='orange', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-12-15'), color='r', linestyle='--', lw=2)
ax.legend()
plt.savefig("../figures/reviews_dec20.png",dpi=600);

# %% [markdown]
# ### 3.6. A decrease of bookings on single rooms renting compare to entire rentals.

# %%
type_room_reviewed_x_day = calendar_reviews.loc[calendar_reviews["reviewed"]==1].groupby("date")["room_type"].value_counts().rename("count").reset_index()

# %%
type_room_reviewed_x_day = calendar_reviews.loc[calendar_reviews["reviewed"]==1].groupby("date")["room_type"].value_counts().rename("count").reset_index()

# %%
type_room_reviewed_x_day = type_room_reviewed_x_day.loc[(type_room_reviewed_x_day["room_type"] == "Entire home/apt") |
                             (type_room_reviewed_x_day["room_type"] == "Private room")]

# %%
type_room_reviewed_x_day.head()
# Out:
#         date        room_type  count
# 0 2018-12-06     Private room     51
# 1 2018-12-06  Entire home/apt     25
# 3 2018-12-07     Private room     58
# 4 2018-12-07  Entire home/apt     33
# 6 2018-12-08     Private room     76

# %%
sns.set_palette(sns.color_palette("tab10"))
sns.set_style("whitegrid")
#sns.set_palette(sns.color_palette("tab10"))
fig,ax = plt.subplots(figsize = (20,5))
sns.lineplot(x="date",y="count", data= type_room_reviewed_x_day, hue= "room_type")
plt.axvline(pd.to_datetime('2020-03-15'), color='r', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-12-15'), color='r', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-07-01'), color='b', linestyle='--', lw=2)
plt.axvline(pd.to_datetime('2020-08-18'), color='r', linestyle='--', lw=2)
plt.savefig("../figures/count_type_room.png",dpi=600)
plt.show();

# %%
#whole period
type_room_reviewed_x_day.loc[type_room_reviewed_x_day["room_type"]== "Private room"]["count"].describe()
# Out:
# count    758.000000
# mean      75.379947
# std       66.707158
# min        1.000000
# 25%       11.000000
# 50%       66.500000
# 75%      122.000000
# max      299.000000
# Name: count, dtype: float64

# %%
#whole period
type_room_reviewed_x_day.loc[type_room_reviewed_x_day["room_type"]== "Entire home/apt"]["count"].describe()

# %%
#Before corona, private room
type_room_reviewed_x_day.loc[(type_room_reviewed_x_day["room_type"]== "Private room")
                            & (type_room_reviewed_x_day["date"] < pd.to_datetime('2020-03-15'))]["count"].describe()
# Out:
# count    367.000000
# mean     128.553134
# std       51.722640
# min        4.000000
# 25%       95.000000
# 50%      121.000000
# 75%      155.500000
# max      299.000000
# Name: count, dtype: float64

# %%
#Before corona, entire apartment
type_room_reviewed_x_day.loc[(type_room_reviewed_x_day["room_type"]== "Entire home/apt")
                            & (type_room_reviewed_x_day["date"] < pd.to_datetime('2020-03-15'))]["count"].describe()
# Out:
# count    367.000000
# mean      76.226158
# std       55.249415
# min        1.000000
# 25%       41.000000
# 50%       59.000000
# 75%       88.500000
# max      441.000000
# Name: count, dtype: float64

# %%
#after corona, private room
type_room_reviewed_x_day.loc[(type_room_reviewed_x_day["room_type"]== "Private room")
                            & (type_room_reviewed_x_day["date"] >= pd.to_datetime('2020-03-15'))]["count"].describe()
# Out:
# count    391.000000
# mean      25.470588
# std       31.123716
# min        1.000000
# 25%        6.000000
# 50%       12.000000
# 75%       32.000000
# max      173.000000
# Name: count, dtype: float64

# %%
#after corona, entire apartmern
type_room_reviewed_x_day.loc[(type_room_reviewed_x_day["room_type"]== "Entire home/apt")
                            & (type_room_reviewed_x_day["date"] >=  pd.to_datetime('2020-03-15'))]["count"].describe()
# Out:
# count    385.000000
# mean      16.706494
# std       24.037288
# min        1.000000
# 25%        4.000000
# 50%        7.000000
# 75%       18.000000
# max      151.000000
# Name: count, dtype: float64
